# %%
import pandas as pd
import numpy as np
from ggplot import *
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser
pd.options.display.mpl_style = 'default'
# Out:
# C:\Users\lioncare\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
pd.set_option('display.max_columns', 410)
pd.set_option('expand_frame_repr', True)

# %%
data_path = '~/Associate_June2017_Data'

# %%
saving_habits=pd.read_csv(data_path+'/saving_hab.txt', sep='|', low_memory=False, encoding = "ISO-8859-1")
demographics1=pd.read_csv(data_path+'/demo.txt', sep='|', low_memory=False, encoding = "ISO-8859-1")

# %%
#df = df stands for dataframe. it is common practice, because you will have to keep writing out the name of the dataset again and again. helps keep it short and clear.

# %%
saving_habits.tail (2)
# Out:
#      surveyid    SubmissionDate         starttime           endtime  \
# 319      1293  2016-10-20 14:06   2016-10-20 9:27   2016-10-20 9:54
# 320      1210  2016-10-18 15:10  2016-10-18 13:05  2016-10-18 13:29
#
#               deviceid  subscriberid simid  devicephonenum admin_infob_time  \
# 319  14:dd:a9:46:e4:16           NaN   NaN             NaN          9:27:51
# 320   c3c56825b28215d7           NaN   NaN             NaN         13:05:21
#
#      admin_infocalc1  admin_infocalc2 Savc1_1 Savc1_2 Savc1_3  Savsamnt_count  \
# 319         0.742089            74209  Invest     NaN     NaN               1
# 320         0.582858            58286  Invest     NaN     NaN               1
#
#          c2_1    c3_1 c2_2  c3_2 c2_3  c3_3   Savc4 Savsg1c6_1 Savsg1c6_2  \
# 319  Kuwekeza  500000  NaN   NaN  NaN   NaN  500000        NaN        NaN
# 320  Kuwekeza  500000  NaN   NaN  NaN   NaN  500000        NaN        NaN
#
# ...

# %%
demographics1.tail (2)
# Out:
#      surveyid  demob2  demob3     demob4      demob5       demob6  \
# 311      1586    Male      26  Single     Standard 7       Driver
# 312      1587  Female      36    Married  Standard 7  Salesperson
#
#     demob6_other demob7 demob8 demob8_other       demob9 demob9_other  \
# 311          NaN     No   Cash          NaN    Every Day          NaN
# 312          NaN     No   Cash          NaN  Every Month          NaN
#
#                demob10 demob11  demob11_other    demob12    demob13  \
# 311  TZS 400000-650000     NaN            NaN  656005567  656005567
# 312  TZS 280000-400000     NaN            NaN  714886502  714886502
#
#        demob15    demob16
# 311  656005567  656005567
# 312  714886502  714886502

# %%
# resource for merging at https://chrisalbon.com/python/pandas_join_merge_dataframe.html
# and https://www.youtube.com/watch?v=h4hOPGo4UVU
# and http://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/

# %%
newdf = pd.merge (saving_habits, demographics1, on="surveyid")

# %%
newdf.tail(20)
# Out:
#      surveyid    SubmissionDate         starttime           endtime  \
# 301      1160  2016-10-10 16:29  2016-10-10 10:59  2016-10-10 11:19
# 302      1156  2016-10-10 16:25  2016-10-10 11:56  2016-10-10 12:26
# 303      1112  2016-10-07 15:01  2016-10-07 10:11  2016-10-07 10:42
# 304      1113  2016-10-07 15:01   2016-10-07 9:23  2016-10-07 10:10
# 305      1319  2016-10-20 14:09  2016-10-20 11:36  2016-10-20 11:59
# 306      1141  2016-10-07 15:04  2016-10-07 10:46  2016-10-07 11:09
# 307      1548  2016-10-31 18:08   2016-10-31 8:48   2016-10-31 9:11
# 308      1353  2016-10-21 13:48  2016-10-21 12:52  2016-10-21 13:30
# 309      1493  2016-10-28 14:27  2016-10-28 12:56  2016-10-28 13:30
# 310      1585  2016-10-06 16:25  2016-10-06 13:26  2016-10-06 13:50
# 311      1192  2016-10-18 14:48  2016-10-18 12:10  2016-10-18 12:41
# 312      1232  2016-10-19 13:41  2016-10-19 11:05  2016-10-19 11:36
# 313      1570  2016-10-06 16:20  2016-10-06 14:16  2016-10-06 14:44
# ...

# %%
# newdata.to_csv('Associate_June2017_Data') to save?

# %%
#But maybe we're good to go, but our data types are all wrong. 
#Perhaps our amounts are a string 1,234,222 and we want them as 1234222 so we can convert them into a numeric value. 
#Then we need to remove the commas. To do this we are going to use str.replace()

# %%
newdf.dtypes
# Out:
# surveyid              int64
# SubmissionDate       object
# starttime            object
# endtime              object
# deviceid             object
# subscriberid        float64
# simid                object
# devicephonenum      float64
# admin_infob_time     object
# admin_infocalc1     float64
# admin_infocalc2       int64
# Savc1_1              object
# Savc1_2              object
# Savc1_3              object
# Savsamnt_count        int64
# c2_1                 object
# c3_1                  int64
# c2_2                 object
# c3_2                float64
# c2_3                 object
# c3_3                float64
# Savc4                 int64
# Savsg1c6_1           object
# Savsg1c6_2           object
# Savsg1c6_3           object
# Savsg1c6_4          float64
# Savsg1c6_5          float64
# Savsg1c6_6          float64
# Savsg1c6_7          float64
# Savsg1c6_8          float64
#                      ...
# trustn3              object
# trustn4              object
# ...

# %%
# why are the () empty below?

# %%
#REASON FOR SAVING: 
#c66 Why do you make contributions to the [c61]?

#PREFERED SAVING VEHICLE:
#c6 Where would you save the amount of money?
#c34 Where would you save the amount of money?
#c58 Which of these do you actually use to save/keep money?
#c59 Specify other?

#DEPOSIT AMOUNT: 
#Savings Habits > savg1 (1)
#c3 How much would you [c2]?
#c31 How much would you [c30] ?
#h1 If you were to receive TZS 5,000 in which of the following locations would you most prefer to save the money?
#h11 If you were to receive TZS 700,000 in which of the following locations would you prefer to place the money?

#h21 Mobile money account (perceptions of safety for saving 1 = safest)
#h29 Accessibility (but in question re-mention safety...)

#n7 Mobile money operators can be trusted
#n8 Mobile money operators would try to take advantage of me if they got a chance

# %%
#REASON FOR SAVING: 
#c66 Why do you make contributions to the [c61]?
newdf.Savsg1c6_6.value_counts().sort_index()
# Out:
# Series([], Name: Savsg1c6_6, dtype: int64)

# %%
#c6 Where would you save the amount of money?
newdf.Savsg1c6_1
# Out:
# 0               In a bank account
# 1               In a bank account
# 2      In my mobile money account
# 3      In my mobile money account
# 4               In a bank account
# 5               In a bank account
# 6                             NaN
# 7                             NaN
# 8      In my mobile money account
# 9      In my mobile money account
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18     In my mobile money account
# 19               In my Kibubu box
# 20                            NaN
# 21                            NaN
# 22     In my mobile money account
# 23     In my mobile money account
# 24     In my mobile money account
# 25                            NaN
# 26                            NaN
# ...

# %%
#c34 Where would you save the amount of money?
newdf.Savsg4c34_1
# Out:
# 0               In a bank account
# 1               In a bank account
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8      In my mobile money account
# 9      In my mobile money account
# 10                            NaN
# 11                            NaN
# 12     In my mobile money account
# 13     In my mobile money account
# 14                            NaN
# 15                            NaN
# 16     In my mobile money account
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22     In my mobile money account
# 23     In my mobile money account
# 24     In my mobile money account
# 25                            NaN
# 26                            NaN
# ...

# %%
#c58 Which of these do you actually use to save/keep money?
newdf.Savc58_1
# Out:
# 0              Bank Account
# 1              Bank Account
# 2      Mobile Money Account
# 3      Mobile Money Account
# 4              Bank Account
# 5              Bank Account
# 6      Mobile Money Account
# 7      Mobile Money Account
# 8      Mobile Money Account
# 9      Mobile Money Account
# 10             Bank Account
# 11             Bank Account
# 12             Bank Account
# 13             Bank Account
# 14     Mobile Money Account
# 15     Mobile Money Account
# 16               Kibubu Box
# 17                   Vicoba
# 18               Kibubu Box
# 19               Kibubu Box
# 20             Bank Account
# 21     Mobile Money Account
# 22                   Vicoba
# 23             Bank Account
# 24             Bank Account
# 25     Mobile Money Account
# 26             Bank Account
# 27     Mobile Money Account
# 28     Mobile Money Account
# 29     Mobile Money Account
#                ...
# 291              Kibubu Box
# 292                  Vicoba
# ...

# %%
newdf.Savsg1c6_6
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 291   NaN
# 292   NaN
# 293   NaN
# 294   NaN
# 295   NaN
# 296   NaN
# 297   NaN
# 298   NaN
# 299   NaN
# 300   NaN
# 301   NaN
# 302   NaN
# 303   NaN
# 304   NaN
# 305   NaN
# 306   NaN
# 307   NaN
# 308   NaN
# 309   NaN
# 310   NaN
# 311   NaN
# 312   NaN
# 313   NaN
# 314   NaN
# 315   NaN
# 316   NaN
# 317   NaN
# 318   NaN
# 319   NaN
# 320   NaN
# Name: Savsg1c6_6, dtype: float64

# %%
newdf.trustn7.value_counts().sort_index()
# Out:
# Neither agree nor disagree     35
# Somewhat agree                 72
# Somewhat disagree              31
# Strongly agree                108
# Strongly disagree              75
# Name: trustn7, dtype: int64

# %%
newdf.surveyid.value_counts().sort_index()
# Out:
# 1112    1
# 1113    1
# 1114    2
# 1115    1
# 1119    1
# 1120    1
# 1121    1
# 1122    1
# 1123    1
# 1125    1
# 1126    1
# 1128    1
# 1132    1
# 1134    1
# 1135    1
# 1137    1
# 1140    1
# 1141    1
# 1142    1
# 1143    1
# 1144    1
# 1147    1
# 1148    1
# 1149    1
# 1150    1
# 1151    1
# 1154    1
# 1155    1
# 1156    1
# 1157    1
#        ..
# 1536    1
# 1538    1
# 1540    1
# 1541    1
# 1543    1
# 1544    1
# 1546    1
# 1548    1
# 1551    1
# 1553    1
# 1554    1
# 1556    1
# 1557    1
# 1558    1
# 1559    1
# 1561    1
# 1562    1
# 1565    1
# 1566    2
# 1567    1
# 1568    1
# 1569    2
# 1570    1
# 1573    1
# 1576    1
# 1577    1
# 1579    1
# 1585    1
# 1586    1
# 1587    1
# Name: surveyid, dtype: int64

# %%
newdf.columns
# Out:
# Index(['surveyid', 'SubmissionDate', 'starttime', 'endtime', 'deviceid',
#        'subscriberid', 'simid', 'devicephonenum', 'admin_infob_time',
#        'admin_infocalc1',
#        ...
#        'demob8_other', 'demob9', 'demob9_other', 'demob10', 'demob11',
#        'demob11_other', 'demob12', 'demob13', 'demob15', 'demob16'],
#       dtype='object', length=395)

# %%
plt.matshow(newdf.corr())
